# %%
#import relevant packages
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-104-6eca7deeba41> in <module>
#       3 import numpy as np
#       4 import seaborn as sns
# ----> 5 import panel as pn
#       6 pn.extension('plotly')
#       7 import plotly.express as px
#
# ModuleNotFoundError: No module named 'panel'

# %%
#import climate data
climate_df = pd.read_csv('data/raw_climate_data.csv')

#drop index column
climate_df = climate_df.drop(climate_df.columns[0], axis = 1)
#convert date column to datetime
climate_df['Date'] = pd.to_datetime(climate_df['Date'])

#set date to index
climate_df = climate_df.set_index(['Date'])

#pull out only pm10 data
pm_10 = climate_df[climate_df['Specie']=='pm10']

# %%
#create dataframe for each country

india = pm_10[pm_10['Country']=='IN']
china = pm_10[pm_10['Country']=='CN']
united_kingdom = pm_10[pm_10['Country']=='GB']
unitied_states = pm_10[pm_10['Country']=='US']
australia = pm_10[pm_10['Country']=='AU']
japan = pm_10[pm_10['Country']=='JP']

# %%
# Average PM10 India
india.groupby('Date')['median'].mean('month').plot()
china.groupby('Date')['median'].mean('month').plot()
united_kingdom.groupby('Date')['median'].mean('month').plot()
unitied_states.groupby('Date')['median'].mean('month').plot()
australia.groupby('Date')['median'].mean('month').plot()
japan.groupby('Date')['median'].mean('month').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Out:
# <AxesSubplot:xlabel='Date', ylabel='median'>

# %%
united_kingdom
# Out:
#            Country             City     Specie  count  min   max  median  \
# Date
# 2020-06-23      GB        Edinburgh  wind-gust    264  0.2  32.5     9.9
# 2020-11-18      GB        Edinburgh  wind-gust    273  4.5  31.9    16.7
# 2020-05-04      GB        Edinburgh  wind-gust    261  0.1  15.0     6.7
# 2020-05-08      GB        Edinburgh  wind-gust    258  0.2  16.5     8.3
# 2020-09-20      GB        Edinburgh  wind-gust    212  0.1   9.0     3.0
# ...            ...              ...        ...    ...  ...   ...     ...
# 2020-03-31      GB  Southend-on-Sea  wind gust     36  0.1  14.6     5.8
# 2020-01-16      GB  Southend-on-Sea  wind gust     48  1.8   7.5     4.8
# 2020-01-23      GB  Southend-on-Sea  wind gust     26  0.1   1.5     0.5
# 2020-02-06      GB  Southend-on-Sea  wind gust     29  0.5   5.0     2.1
# 2020-03-21      GB  Southend-on-Sea  wind gust     37  5.3  25.0     9.5
#
#             variance
# Date
# 2020-06-23    526.23
# 2020-11-18    357.79
# 2020-05-04    149.49
# 2020-05-08    238.91
# 2020-09-20     36.89
# ...              ...
# 2020-03-31    153.69
# 2020-01-16     32.57
# 2020-01-23      1.63
# 2020-02-06     13.62
# 2020-03-21    309.51
#
# [70034 rows x 8 columns]

# %%
climate_df['Date'] = pd.to_datetime(climate_df['Date'])
climate_df['Date']
# Out:
# 0        2020-01-06
# 1        2020-03-20
# 2        2020-04-05
# 3        2020-05-31
# 4        2020-06-15
#             ...
# 714463   2020-08-09
# 714464   2020-09-10
# 714465   2020-09-21
# 714466   2020-10-28
# 714467   2020-11-14
# Name: Date, Length: 714468, dtype: datetime64[ns]
